# %%
import pandas as pd

# %%
columnNames = ["Id", "#", "trial", "X"]
trial = pd.read_csv("trialdata.csv", names=columnNames, header=None)

# %%
rt = []
trial_type = []
responses = []
view_history = []
internal_node_id = []
time_elapsed = []
questions = []
trial_index = []

# %%
for e in trial.X:
    e = e.replace('true', 'True')
    e = e.replace('false', 'False')
    d = eval(e)
    
    rt.append(d['rt'])
    trial_type.append(d['trial_type'])
    internal_node_id.append(d['internal_node_id'])
    time_elapsed.append(d['time_elapsed'])
    trial_index.append(d['trial_index'])

    try:
        responses.append(d['responses'])
    except KeyError:
        responses.append(None)
    try:
        view_history.append(d['view_history'])
    except KeyError:
        view_history.append(None)
    try:
        questions.append(d['questions'])
    except KeyError:
        questions.append(None)

# %%
# 'X' is replaced, '#' == trial_index
trial = trial.drop(['X', '#'], axis = 1)

# %%
trial['rt'] = rt
trial['trial_type'] = trial_type
trial['internal_node_id'] = internal_node_id
trial['time_elapsed'] = time_elapsed
trial['trial_index'] = trial_index
trial['responses'] = responses
trial['view_history'] = view_history
trial['questions'] = questions

# %%
prompt = []
labels = []
required = []
options = []
horizontal = []

# %%
# Does this work for demographics?
for q in trial.questions:
    if q == None:
        prompt.append(None)
        labels.append(None)
        required.append(None)
        options.append(None)
        horizontal.append(None)
    else:
        d = eval(q.replace('true', 'True').replace('false', 'False'))[0]
        prompt.append(d['prompt'])
        required.append(d['required'])

        try:
            labels.append(d['labels'])
        except KeyError:
            labels.append(None)
        try:
            options.append(d['options'])
        except KeyError:
            options.append(None)
        try:
            horizontal.append(d['horizontal'])
        except:
            horizontal.append(None)

# %%
trial = trial.drop(['questions'], axis = 1)

# %%
trial['prompt'] = prompt
trial['required'] = required
trial['labels'] = labels
trial['options'] = options
trial['horizontal'] = horizontal

# %%
trial
# Out:
#                           Id          trial     rt               trial_type  \
# 0    debugC9Q0J2:debugRW0BVN  1540317457046   3138             instructions
# 1    debugC9Q0J2:debugRW0BVN  1540317468282  11233  face-prisdil-continuous
# 2    debugC9Q0J2:debugRW0BVN  1540317473819   5534        face-multi-choice
# 3    debugC9Q0J2:debugRW0BVN  1540317476192   2370              face-likert
# 4    debugC9Q0J2:debugRW0BVN  1540317482323   6131              face-likert
# 5    debugC9Q0J2:debugRW0BVN  1540317485700   3376              face-likert
# 6    debugC9Q0J2:debugRW0BVN  1540317487774   2073              face-likert
# 7    debugC9Q0J2:debugRW0BVN  1540317490406   2630              face-likert
# 8    debugC9Q0J2:debugRW0BVN  1540317493621   3215              face-likert
# 9    debugC9Q0J2:debugRW0BVN  1540317498584   4961              face-likert
# 10   debugC9Q0J2:debugRW0BVN  1540317538020  39433  face-prisdil-continuous
# 11   debugC9Q0J2:debugRW0BVN  1540317543024   5002        face-multi-choice
# 12   debugC9Q0J2:debugRW0BVN  1540317547823   4796              face-likert
# 13   debugC9Q0J2:debugRW0BVN  1540317554950   7127              face-likert
# 14   debugC9Q0J2:debugRW0BVN  1540317560847   5895              face-likert
# 15   debugC9Q0J2:debugRW0BVN  1540317566126   5277              face-likert
# 16   debugC9Q0J2:debugRW0BVN  1540317570348   4221              face-likert
# 17   debugC9Q0J2:debugRW0BVN  1540317582279  11928              face-likert
# 18   debugC9Q0J2:debugRW0BVN  1540317586348   4069              face-likert
# 19   debugG056JE:debugCOYUIT  1541028825405  23955             instructions
# 20   debugG056JE:debugCOYUIT  1541028826782   1377             instructions
# 21   debugG056JE:debugCOYUIT  1541028837070  10284        face-multi-choice
# 22   debugG056JE:debugCOYUIT  1541028840752   3681        face-multi-choice
# 23   debugG056JE:debugCOYUIT  1541028843396   2639  face-prisdil-continuous
# 24   debugG056JE:debugCOYUIT  1541028845963   2565        face-multi-choice
# 25   debugG056JE:debugCOYUIT  1541028848408   2442              face-likert
# 26   debugG056JE:debugCOYUIT  1541028850090   1680              face-likert
# 27   debugG056JE:debugCOYUIT  1541028851733   1642              face-likert
# 28   debugG056JE:debugCOYUIT  1541028857786   6051              face-likert
# 29   debugG056JE:debugCOYUIT  1541028861462   3675              face-likert
# ..                       ...            ...    ...                      ...
# 136  debugAPDDQI:debugU8E81D  1541465708527   3448              face-likert
# 137  debugAPDDQI:debugU8E81D  1541465712773   4244              face-likert
# 138  debugAPDDQI:debugU8E81D  1541465716451   3677              face-likert
# 139  debugAPDDQI:debugU8E81D  1541465719549   3097              face-likert
# 140  debugAPDDQI:debugU8E81D  1541465726548   6997              face-likert
# 141  debugAPDDQI:debugU8E81D  1541465731286   4737              face-likert
# 142  debugAPDDQI:debugU8E81D  1541465737303   6015              face-likert
# 143  debugAPDDQI:debugU8E81D  1541465740271   2966              face-likert
# 144  debugAPDDQI:debugU8E81D  1541465746176   5904              face-likert
# 145  debugAPDDQI:debugU8E81D  1541465750851   4673              face-likert
# 146  debugAPDDQI:debugU8E81D  1541465754017   3165              face-likert
# 147  debugAPDDQI:debugU8E81D  1541465757205   3186              face-likert
# 148  debugAPDDQI:debugU8E81D  1541465770379  13174              face-likert
# 149  debugAPDDQI:debugU8E81D  1541465772763   2383              face-likert
# 150  debugAPDDQI:debugU8E81D  1541465777243   4479              face-likert
# 151  debugAPDDQI:debugU8E81D  1541465779345   2101              face-likert
# 152  debugAPDDQI:debugU8E81D  1541465782322   2975              face-likert
# 153  debugAPDDQI:debugU8E81D  1541465786137   3815              face-likert
# 154  debugAPDDQI:debugU8E81D  1541465790950   4812              face-likert
# 155  debugAPDDQI:debugU8E81D  1541465793357   2406              face-likert
# 156  debugAPDDQI:debugU8E81D  1541465796329   2971              face-likert
# 157  debugAPDDQI:debugU8E81D  1541465800898   4568              face-likert
# 158  debugAPDDQI:debugU8E81D  1541465804439   3540              face-likert
# 159  debugAPDDQI:debugU8E81D  1541465808588   4148              face-likert
# 160  debugAPDDQI:debugU8E81D  1541465812625   4034              face-likert
# 161  debugAPDDQI:debugU8E81D  1541465815018   2392              face-likert
# 162  debugAPDDQI:debugU8E81D  1541465820265   5244              face-likert
# 163  debugAPDDQI:debugU8E81D  1541465824707   4440              face-likert
# 164  debugAPDDQI:debugU8E81D  1541465828685   3976              face-likert
# 165  debugAPDDQI:debugU8E81D  1541465832037   3350              face-likert
#
#     internal_node_id  time_elapsed  trial_index              responses  \
# 0            0.0-0.0          3141            0                   None
# 1            0.0-1.0         14378            1  {"slider_value":"62"}
# 2            0.0-2.0         19915            2        {"Q0":"Play A"}
# 3            0.0-3.0         22288            3               {"Q0":8}
# 4            0.0-4.0         28419            4               {"Q0":7}
# 5            0.0-5.0         31796            5               {"Q0":2}
# 6            0.0-6.0         33870            6               {"Q0":7}
# 7            0.0-7.0         36502            7               {"Q0":7}
# 8            0.0-8.0         39717            8               {"Q0":8}
# 9            0.0-9.0         44680            9               {"Q0":6}
# 10          0.0-10.0         84116           10  {"slider_value":"63"}
# 11          0.0-11.0         89120           11        {"Q0":"Play A"}
# 12          0.0-12.0         93919           12               {"Q0":7}
# 13          0.0-13.0        101046           13               {"Q0":3}
# 14          0.0-14.0        106943           14               {"Q0":8}
# 15          0.0-15.0        112222           15               {"Q0":8}
# 16          0.0-16.0        116444           16               {"Q0":8}
# 17          0.0-17.0        128375           17               {"Q0":7}
# 18          0.0-18.0        132444           18               {"Q0":6}
# 19           0.0-0.0         23958            0                   None
# 20           0.0-1.0         25335            1                   None
# 21           0.0-2.0         35623            2        {"Q0":"Play B"}
# 22           0.0-3.0         39305            3        {"Q0":"Play A"}
# 23           0.0-4.0         41949            4  {"slider_value":"50"}
# 24           0.0-5.0         44516            5        {"Q0":"Play B"}
# 25           0.0-6.0         46961            6               {"Q0":7}
# 26           0.0-7.0         48642            7               {"Q0":6}
# 27           0.0-8.0         50286            8               {"Q0":4}
# 28           0.0-9.0         56339            9               {"Q0":2}
# 29          0.0-10.0         60015           10               {"Q0":8}
# ..               ...           ...          ...                    ...
# 136         0.0-93.0        541383           93               {"Q0":6}
# 137         0.0-94.0        545629           94               {"Q0":5}
# 138         0.0-95.0        549307           95               {"Q0":3}
# 139         0.0-96.0        552405           96               {"Q0":4}
# 140         0.0-97.0        559404           97               {"Q0":3}
# 141         0.0-98.0        564142           98               {"Q0":6}
# 142         0.0-99.0        570159           99               {"Q0":6}
# 143        0.0-100.0        573127          100               {"Q0":4}
# 144        0.0-101.0        579032          101               {"Q0":5}
# 145        0.0-102.0        583707          102               {"Q0":3}
# 146        0.0-103.0        586873          103               {"Q0":3}
# 147        0.0-104.0        590061          104               {"Q0":4}
# 148        0.0-105.0        603235          105               {"Q0":8}
# 149        0.0-106.0        605619          106               {"Q0":6}
# 150        0.0-107.0        610099          107               {"Q0":5}
# 151        0.0-108.0        612201          108               {"Q0":6}
# 152        0.0-109.0        615178          109               {"Q0":5}
# 153        0.0-110.0        618993          110               {"Q0":4}
# 154        0.0-111.0        623806          111               {"Q0":3}
# 155        0.0-112.0        626213          112               {"Q0":4}
# 156        0.0-113.0        629185          113               {"Q0":2}
# 157        0.0-114.0        633754          114               {"Q0":3}
# 158        0.0-115.0        637295          115               {"Q0":4}
# 159        0.0-116.0        641444          116               {"Q0":6}
# 160        0.0-117.0        645481          117               {"Q0":6}
# 161        0.0-118.0        647874          118               {"Q0":7}
# 162        0.0-119.0        653121          119               {"Q0":6}
# 163        0.0-120.0        657563          120               {"Q0":7}
# 164        0.0-121.0        661541          121               {"Q0":4}
# 165        0.0-122.0        664893          122               {"Q0":4}
#
#                                 view_history  \
# 0     [{"page_index":0,"viewing_time":3138}]
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# 5                                       None
# 6                                       None
# 7                                       None
# 8                                       None
# 9                                       None
# 10                                      None
# 11                                      None
# 12                                      None
# 13                                      None
# 14                                      None
# 15                                      None
# 16                                      None
# 17                                      None
# 18                                      None
# 19   [{"page_index":0,"viewing_time":23954}]
# 20    [{"page_index":0,"viewing_time":1377}]
# 21                                      None
# 22                                      None
# 23                                      None
# 24                                      None
# 25                                      None
# 26                                      None
# 27                                      None
# 28                                      None
# 29                                      None
# ..                                       ...
# 136                                     None
# 137                                     None
# 138                                     None
# 139                                     None
# 140                                     None
# 141                                     None
# 142                                     None
# 143                                     None
# 144                                     None
# 145                                     None
# 146                                     None
# 147                                     None
# 148                                     None
# 149                                     None
# 150                                     None
# 151                                     None
# 152                                     None
# 153                                     None
# 154                                     None
# 155                                     None
# 156                                     None
# 157                                     None
# 158                                     None
# 159                                     None
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
# 165                                     None
#
#                                                 prompt required  \
# 0                                                 None     None
# 1    You can see the other person&#8217;s picture, ...     True
# 2                                           Would you:     True
# 3    How willing or unwilling do you think this per...     True
# 4    How willing do you think this person is to giv...     True
# 5    How willing do you think this person is to giv...     True
# 6    <i>Please tell us how well you think the follo...     True
# 7    How willing do you think this person is to pun...     True
# 8    <i>Please tell us how well you think the follo...     True
# 9    How attractive (i.e., appealing to the senses ...     True
# 10   You can see the other person&#8217;s picture, ...     True
# 11                                          Would you:     True
# 12   How willing or unwilling do you think this per...     True
# 13   How willing do you think this person is to giv...     True
# 14   How willing do you think this person is to giv...     True
# 15   <i>Please tell us how well you think the follo...     True
# 16   How willing do you think this person is to pun...     True
# 17   <i>Please tell us how well you think the follo...     True
# 18   How attractive (i.e., appealing to the senses ...     True
# 19                                                None     None
# 20                                                None     None
# 21     What do you think the other person will choose?     True
# 22     What do you think the other person will choose?     True
# 23   You can see the other person&#8217;s picture, ...     True
# 24                                          Would you:     True
# 25   How willing or unwilling do you think this per...     True
# 26   How willing do you think this person is to giv...     True
# 27   How willing do you think this person is to giv...     True
# 28   <i>Please tell us how well you think the follo...     True
# 29   How willing do you think this person is to pun...     True
# ..                                                 ...      ...
# 136  How willing or unwilling do you think this per...     True
# 137  How willing or unwilling do you think this per...     True
# 138  How willing or unwilling do you think this per...     True
# 139  How willing or unwilling do you think this per...     True
# 140  How willing or unwilling do you think this per...     True
# 141  How willing or unwilling do you think this per...     True
# 142  How willing or unwilling do you think this per...     True
# 143  How willing or unwilling do you think this per...     True
# 144  How willing or unwilling do you think this per...     True
# 145  How willing or unwilling do you think this per...     True
# 146  How willing or unwilling do you think this per...     True
# 147  How willing or unwilling do you think this per...     True
# 148  How willing or unwilling do you think this per...     True
# 149  How willing or unwilling do you think this per...     True
# 150  How willing or unwilling do you think this per...     True
# 151  How willing or unwilling do you think this per...     True
# 152  How willing or unwilling do you think this per...     True
# 153  How willing or unwilling do you think this per...     True
# 154  How willing or unwilling do you think this per...     True
# 155  How willing or unwilling do you think this per...     True
# 156  How willing or unwilling do you think this per...     True
# 157  How willing or unwilling do you think this per...     True
# 158  How willing or unwilling do you think this per...     True
# 159  How willing or unwilling do you think this per...     True
# 160  How willing or unwilling do you think this per...     True
# 161  How willing or unwilling do you think this per...     True
# 162  How willing or unwilling do you think this per...     True
# 163  How willing or unwilling do you think this per...     True
# 164  How willing or unwilling do you think this per...     True
# 165  How willing or unwilling do you think this per...     True
#
#                                                 labels           options  \
# 0                                                 None              None
# 1                                                 None  [Play A, Play B]
# 2                                                 None  [Play A, Play B]
# 3    [0 (Completely unwilling to take risks), 1, 2,...              None
# 4    [0 (Completely unwilling to do so), 1, 2, 3, 4...              None
# 5    [0 (Completely unwilling to do so), 1, 2, 3, 4...              None
# 6    [0 (Does not describe them at all), 1, 2, 3, 4...              None
# 7    [0 (Completely unwilling to do so), 1, 2, 3, 4...              None
# 8    [0 (Does not describe them at all), 1, 2, 3, 4...              None
# 9      [1 (not at all), 2, 3, 4, 5, 6, 7, 8, 9 (very)]              None
# 10                                                None  [Play A, Play B]
# 11                                                None  [Play A, Play B]
# 12   [0 (Completely unwilling to take risks), 1, 2,...              None
# 13   [0 (Completely unwilling to do so), 1, 2, 3, 4...              None
# 14   [0 (Completely unwilling to do so), 1, 2, 3, 4...              None
# 15   [0 (Does not describe them at all), 1, 2, 3, 4...              None
# 16   [0 (Completely unwilling to do so), 1, 2, 3, 4...              None
# 17   [0 (Does not describe them at all), 1, 2, 3, 4...              None
# 18     [1 (not at all), 2, 3, 4, 5, 6, 7, 8, 9 (very)]              None
# 19                                                None              None
# 20                                                None              None
# 21   [I think he/she will definitely choose A, 2, 3...  [Play A, Play B]
# 22   [I think he/she will definitely choose A, 2, 3...  [Play A, Play B]
# 23                                                None  [Play A, Play B]
# 24                                                None  [Play A, Play B]
# 25   [0 (Completely unwilling to take risks), 1, 2,...              None
# 26   [0 (Completely unwilling to do so), 1, 2, 3, 4...              None
# 27   [0 (Completely unwilling to do so), 1, 2, 3, 4...              None
# 28   [0 (Does not describe them at all), 1, 2, 3, 4...              None
# 29   [0 (Completely unwilling to do so), 1, 2, 3, 4...              None
# ..                                                 ...               ...
# 136  [0 (Completely unwilling to take risks), 1, 2,...              None
# 137  [0 (Completely unwilling to take risks), 1, 2,...              None
# 138  [0 (Completely unwilling to take risks), 1, 2,...              None
# 139  [0 (Completely unwilling to take risks), 1, 2,...              None
# 140  [0 (Completely unwilling to take risks), 1, 2,...              None
# 141  [0 (Completely unwilling to take risks), 1, 2,...              None
# 142  [0 (Completely unwilling to take risks), 1, 2,...              None
# 143  [0 (Completely unwilling to take risks), 1, 2,...              None
# 144  [0 (Completely unwilling to take risks), 1, 2,...              None
# 145  [0 (Completely unwilling to take risks), 1, 2,...              None
# 146  [0 (Completely unwilling to take risks), 1, 2,...              None
# 147  [0 (Completely unwilling to take risks), 1, 2,...              None
# 148  [0 (Completely unwilling to take risks), 1, 2,...              None
# 149  [0 (Completely unwilling to take risks), 1, 2,...              None
# 150  [0 (Completely unwilling to take risks), 1, 2,...              None
# 151  [0 (Completely unwilling to take risks), 1, 2,...              None
# 152  [0 (Completely unwilling to take risks), 1, 2,...              None
# 153  [0 (Completely unwilling to take risks), 1, 2,...              None
# 154  [0 (Completely unwilling to take risks), 1, 2,...              None
# 155  [0 (Completely unwilling to take risks), 1, 2,...              None
# 156  [0 (Completely unwilling to take risks), 1, 2,...              None
# 157  [0 (Completely unwilling to take risks), 1, 2,...              None
# 158  [0 (Completely unwilling to take risks), 1, 2,...              None
# 159  [0 (Completely unwilling to take risks), 1, 2,...              None
# 160  [0 (Completely unwilling to take risks), 1, 2,...              None
# 161  [0 (Completely unwilling to take risks), 1, 2,...              None
# 162  [0 (Completely unwilling to take risks), 1, 2,...              None
# 163  [0 (Completely unwilling to take risks), 1, 2,...              None
# 164  [0 (Completely unwilling to take risks), 1, 2,...              None
# 165  [0 (Completely unwilling to take risks), 1, 2,...              None
#
#     horizontal
# 0         None
# 1        False
# 2        False
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 9         None
# 10       False
# 11       False
# 12        None
# 13        None
# 14        None
# 15        None
# 16        None
# 17        None
# 18        None
# 19        None
# 20        None
# 21       False
# 22       False
# 23       False
# 24       False
# 25        None
# 26        None
# 27        None
# 28        None
# 29        None
# ..         ...
# 136       None
# 137       None
# 138       None
# 139       None
# 140       None
# 141       None
# 142       None
# 143       None
# 144       None
# 145       None
# 146       None
# 147       None
# 148       None
# 149       None
# 150       None
# 151       None
# 152       None
# 153       None
# 154       None
# 155       None
# 156       None
# 157       None
# 158       None
# 159       None
# 160       None
# 161       None
# 162       None
# 163       None
# 164       None
# 165       None
#
# [166 rows x 14 columns]
